# %%
print("Name")
print("Build a GUI application for data visualization of word population and on various other parameters of world population")
# Out:
# Name
# Build a GUI application for data visualization of word population and on various other parameters of world population

# %% [markdown]
# # Task - Build a GUI application for data visualization of word population and on various other parameters of world population

# %%
#image 
#predefine code for image
from IPython.display import Image
Image(filename='map.jpg') 
#predefine code end
from ipywidgets import widgets
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, clear_output
graph_type = ['Choose One...', 'Bar', 'Bubble']
df = pd.read_csv('population_by_country_2020.csv')

def print_dataframe(b):
    global df
    display(df)
    head_tail_list = ['head', 'tail']
    xlabel_widget = widgets.Dropdown(options = df.columns)
    ylabel_widget = widgets.Dropdown(options = df.columns)
    graph_widget = widgets.Dropdown(options = graph_type)
    head_tail_widget = widgets.Dropdown(options = head_tail_list)
    row_range_widget = widgets.Dropdown(options = [10, 20, 30])
    graph = widgets.interactive(display_plot, xaxis = xlabel_widget, yaxis = ylabel_widget, head_tail = head_tail_widget, number = row_range_widget, graph_type = graph_widget)
    display(graph)
def display_plot(xlabel_widget, ylabel_widget, head_tail_widget, row_range_widget, graph_widget):
    global df
    if(head_tail == 'head'):
        dataframe = df.head(10)
    else:
        dataframe = df.tail(10)
    if(graph_type == 'Bubble'):
        if(yaxis.dtypes == 'int64'):
            plt.subplots(figure(20, 8))
            rgb = np.random.rand(3)
            plt.scatter(dataframe[xaxis], dataframe[yaxis], c = rgb, alpha = 0.4, s = dataframe[yaxis]/40000)
            plt.xlabel(xaxis)
            plt.ylabel(yaxis)
            plt.xticks(rotation = 'vertical')
            plt.show()
        else:
            print('Bubble graph cant be displayed')
    elif(graph_type == 'Bar'):
        plt.bar(dataframe[xaxis], dataframe[yaxis], color=['red', 'green','blue','yellow','pink'])
        plt.xlabel(xaxis)
        plt.ylabel(yaxis)
        plt.xticks(rotation = 'vertical')
        plt.show()
    else:
        print('Choose valid graph')
show_dataframe = widgets.Button(description = 'Show Dataframe')
show_dataframe.on_click(print_dataframe)
display(show_dataframe)
# Out:
# Button(description='Show Dataframe', style=ButtonStyle())
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# 1                464          2973190       -532687.0        2.2       28
# 2                 36          9147420        954806.0        1.8       38
# 3                151          1811570        -98955.0        2.3       30
# 4                287           770880       -233379.0        3.6       23
# ..               ...              ...             ...        ...      ...
# 230               50              100             NaN       N.A.     N.A.
# 231                0            12170             NaN       N.A.     N.A.
# 232                6              260             NaN       N.A.     N.A.
# 233              136               10             NaN       N.A.     N.A.
# 234             2003                0             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 0          61 %     18.47 %
# 1          35 %     17.70 %
# 2          83 %      4.25 %
# 3          56 %      3.51 %
# 4          35 %      2.83 %
# ..          ...         ...
# 230        10 %      0.00 %
# 231        66 %      0.00 %
# 232        46 %      0.00 %
# 233         0 %      0.00 %
# 234        N.A.      0.00 %
#
# [235 rows x 11 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21984\1214086954.py in print_dataframe(b)
#      21     head_tail_widget = widgets.Dropdown(options = head_tail_list)
#      22     row_range_widget = widgets.Dropdown(options = [10, 20, 30])
# ---> 23     graph = widgets.interactive(display_plot, xaxis = xlabel_widget, yaxis = ylabel_widget, head_tail = head_tail_widget, number = row_range_widget, graph_type = graph_widget)
#      24     display(graph)
#      25 def display_plot(xlabel_widget, ylabel_widget, head_tail_widget, row_range_widget, graph_widget):
#
# ~\anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in __init__(self, _interactive__interact_f, _interactive__options, **kwargs)
#     187         self.auto_display = __options.get("auto_display", False)
#     188
# --> 189         new_kwargs = self.find_abbreviations(kwargs)
#     190         # Before we proceed, let's make sure that the user has passed a set of args+kwargs
#     191         # that will lead to a valid call of the function. This protects against unspecified
#
# ~\anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in find_abbreviations(self, kwargs)
#     287             for name, value, default in _yield_abbreviations_for_parameter(param, kwargs):
#     288                 if value is empty:
# --> 289                     raise ValueError('cannot find widget or abbreviation for argument: {!r}'.format(name))
#     290                 new_kwargs.append((name, value, default))
#     291         return new_kwargs
#
# ValueError: cannot find widget or abbreviation for argument: 'xlabel_widget'
